# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Solve HW:

# %%
data = pd.read_csv("/content/drive/MyDrive/copy of cancer data set_NA.csv")
data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 22 columns]

# %%
data.drop('id',axis=1,inplace=True)
data.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 21 columns]

# %%
def numeric(x):
    if x=='M':
        return 1
    else:
        return 0

# %%
data['diagnosis']=data['diagnosis'].apply(numeric) #lambda x: 1 if x=='M' else 0
data.head()
# Out:
#    diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          1        17.99  ...          0.4601                  0.11890
# 1          1        20.57  ...          0.2750                  0.08902
# 2          1        19.69  ...          0.3613                  0.08758
# 3          1        11.42  ...          0.6638                  0.17300
# 4          1        20.29  ...          0.2364                  0.07678
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# count  569.000000   566.000000  ...      569.000000               569.000000
# mean     0.372583    14.116924  ...        0.290076                 0.083946
# std      0.483918     3.528045  ...        0.061867                 0.018061
# min      0.000000     6.981000  ...        0.156500                 0.055040
# 25%      0.000000    11.692500  ...        0.250400                 0.071460
# 50%      0.000000    13.320000  ...        0.282200                 0.080040
# 75%      1.000000    15.772500  ...        0.317900                 0.092080
# max      1.000000    28.110000  ...        0.663800                 0.207500
#
# [8 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              566 non-null    float64
#  2   texture_mean             445 non-null    float64
#  3   perimeter_mean           564 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          567 non-null    float64
#  6   compactness_mean         565 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      568 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_worst             569 non-null    float64
#  12  texture_worst            569 non-null    float64
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.isna())

# %%
data.isna().sum()
# Out:
# diagnosis                    0
# radius_mean                  3
# texture_mean               124
# perimeter_mean               5
# area_mean                    0
# smoothness_mean              2
# compactness_mean             4
# concavity_mean               0
# concave points_mean          1
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# dtype: int64

# %%
for c in range(len(data.columns)):
    if data.isna().sum()[c]!=0:
        data[data.columns[c]]=data[data.columns[c]].fillna(data[data.columns[c]].mean())

# %%
data.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ## Outliers:

# %%
sns.boxplot(data['diagnosis'],data['area_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import scipy.stats as stats

# %%
#zscore conversion
original=data.copy()

# %%
data=data[data.columns[1:]].apply(stats.zscore)
data.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0     1.101676     -2.336771  ...        2.750622                 1.937015
# 1     1.835543     -0.390532  ...       -0.243890                 0.281190
# 2     1.585232      0.525965  ...        1.152255                 0.201391
# 3    -0.767126      0.296841  ...        6.046041                 4.935010
# 4     1.755899     -1.293861  ...       -0.868353                -0.397100
#
# [5 rows x 20 columns]

# %%
data.describe()
# Out:
#         radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# count  5.690000e+02  5.690000e+02  ...    5.690000e+02             5.690000e+02
# mean   8.468133e-17  4.046753e-16  ...    1.670212e-16             2.321908e-16
# std    1.000880e+00  1.000880e+00  ...    1.000880e+00             1.000880e+00
# min   -2.029776e+00 -2.513223e+00  ...   -2.160960e+00            -1.601839e+00
# 25%   -6.874812e-01 -5.959539e-01  ...   -6.418637e-01            -6.919118e-01
# 50%   -2.124586e-01  0.000000e+00  ...   -1.274095e-01            -2.164441e-01
# 75%    4.645198e-01  4.232540e-01  ...    4.501382e-01             4.507624e-01
# max    3.980256e+00  5.274367e+00  ...    6.046041e+00             6.846856e+00
#
# [8 rows x 20 columns]

# %%
#Remove outliers based on zscore
for i in data.columns:
    ind = data[ ((data[i] >=3) | (data[i]<=-3))].index
    data.drop(ind,inplace=True)
    original.drop(ind,inplace=True)
    #df.reset_index()
    
print(len(data))
print(len(original))
# Out:
# 515
# 515

# %%
sns.boxplot(original['diagnosis'],original['area_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
#  Go back to Get Dummies if we have time...

# %%
original
# Out:
#      diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 1            1        20.57  ...          0.2750                  0.08902
# 2            1        19.69  ...          0.3613                  0.08758
# 4            1        20.29  ...          0.2364                  0.07678
# 5            1        12.45  ...          0.3985                  0.12440
# 6            1        18.25  ...          0.3063                  0.08368
# ..         ...          ...  ...             ...                      ...
# 561          0        11.20  ...          0.1566                  0.05905
# 563          1        20.92  ...          0.2929                  0.09873
# 564          1        21.56  ...          0.2060                  0.07115
# 565          1        20.13  ...          0.2572                  0.06637
# 566          1        16.60  ...          0.2218                  0.07820
#
# [515 rows x 21 columns]

# %%
sns.distplot(original['radius_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
